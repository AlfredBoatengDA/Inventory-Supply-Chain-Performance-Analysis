# %%
import pandas as pd
import numpy as np
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\Nicole Macauley\Desktop\Projects In Progress\Inventory_SupplyChain_Dataset.csv")
data
# Out:
#             Date Region     Category    Supplier    Warehouse Order Status  \
# 0     14-01-2020  North  Accessories  Supplier A  Warehouse 1    Fulfilled
# 1     15-11-2020   East    Furniture  Supplier D  Warehouse 2    Fulfilled
# 2     16-04-2020   East    Furniture  Supplier C  Warehouse 2    Fulfilled
# 3     17-04-2020  South  Accessories  Supplier D  Warehouse 2     Canceled
# 4     18-04-2020  North  Accessories  Supplier C  Warehouse 2    Fulfilled
# ...          ...    ...          ...         ...          ...          ...
# 1195  05-01-2023   East  Electronics  Supplier C  Warehouse 2      Pending
# 1196  04-01-2023   East     Clothing  Supplier A  Warehouse 3    Fulfilled
# 1197  03-01-2023  North  Accessories  Supplier C  Warehouse 2    Fulfilled
# 1198  02-01-2023   West     Clothing  Supplier D  Warehouse 1      Pending
# 1199  01-01-2023   East  Electronics  Supplier A  Warehouse 1    Fulfilled
#
# ...

# %%
data.head()
# Out:
#          Date Region     Category    Supplier    Warehouse Order Status  \
# 0  14-01-2020  North  Accessories  Supplier A  Warehouse 1    Fulfilled
# 1  15-11-2020   East    Furniture  Supplier D  Warehouse 2    Fulfilled
# 2  16-04-2020   East    Furniture  Supplier C  Warehouse 2    Fulfilled
# 3  17-04-2020  South  Accessories  Supplier D  Warehouse 2     Canceled
# 4  18-04-2020  North  Accessories  Supplier C  Warehouse 2    Fulfilled
#
#    Units Sold  Inventory Level  Transportation Cost  Order Accuracy  \
# 0         302             2124          1103.838324            True
# 1         741             1972         13163.007660            True
# 2         940              454          9872.294126            True
# 3         589             1867          4547.589932            True
# 4         964             4862         11994.042310            True
#
#    Lead Time (Days)  Backorder  Cost of Goods Sold (COGS)  Average Inventory  \
# ...

# %% [markdown]
# Data Structure

# %%
# We display a sample of our data to view it.
data.sample(20)
# Out:
#             Date Region     Category    Supplier    Warehouse Order Status  \
# 1134  07-03-2023  South    Furniture  Supplier C  Warehouse 2      Pending
# 105   01-01-2022  South  Accessories  Supplier C  Warehouse 1      Pending
# 1034  15-06-2023  North     Clothing  Supplier D  Warehouse 1    Fulfilled
# 873   23-11-2023   East    Furniture  Supplier D  Warehouse 1    Fulfilled
# 1175  25-01-2023   West  Electronics  Supplier C  Warehouse 2    Fulfilled
# 730   14-04-2024   West  Accessories  Supplier C  Warehouse 2    Fulfilled
# 900   27-10-2023   West    Furniture  Supplier B  Warehouse 1    Fulfilled
# 596   26-08-2024  South  Accessories  Supplier D  Warehouse 1    Fulfilled
# 941   16-09-2023   West     Clothing  Supplier C  Warehouse 2      Pending
# 1068  12-05-2023  North     Clothing  Supplier B  Warehouse 2    Fulfilled
# 380   03-10-2022  North  Accessories  Supplier D  Warehouse 2      Pending
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       1200 non-null   object
#  1   Region                     1200 non-null   object
#  2   Category                   1200 non-null   object
#  3   Supplier                   1200 non-null   object
#  4   Warehouse                  1200 non-null   object
#  5   Order Status               1200 non-null   object
#  6   Units Sold                 1200 non-null   int64
#  7   Inventory Level            1200 non-null   int64
#  8   Transportation Cost        1200 non-null   float64
#  9   Order Accuracy             1200 non-null   bool
#  10  Lead Time (Days)           1200 non-null   int64
#  11  Backorder                  1200 non-null   bool
#  12  Cost of Goods Sold (COGS)  1200 non-null   float64
# ...

# %%
# Observations:
In our dataset, there are 6 columns with object Datatype,
4 column which is int Datatype,
3 column which is an float Datatype
2 column which is an bool Datatype

# %%
# Lets check the Unique values present in the Data
data.nunique()
# Out:
# Date                         1200
# Region                          4
# Category                        4
# Supplier                        4
# Warehouse                       3
# Order Status                    3
# Units Sold                    683
# Inventory Level              1069
# Transportation Cost          1200
# Order Accuracy                  2
# Lead Time (Days)               29
# Backorder                       2
# Cost of Goods Sold (COGS)    1200
# Average Inventory            1103
# Warehouse Capacity           1044
# dtype: int64

# %%
data.shape
# Out:
# (1200, 15)

# %%
# Number of rows in the data: 1200
# Number of columns in the data: 15

# %%
# Lets look at the names of columns we have
data.columns
# Out:
# Index(['Date', 'Region', 'Category', 'Supplier', 'Warehouse', 'Order Status',
#        'Units Sold', 'Inventory Level', 'Transportation Cost',
#        'Order Accuracy', 'Lead Time (Days)', 'Backorder',
#        'Cost of Goods Sold (COGS)', 'Average Inventory', 'Warehouse Capacity'],
#       dtype='object')

# %% [markdown]
# Renaming Column

# %%
data.rename(columns = {"Cost of Goods Sold (COGS)" : "Cost of Goods Sold"}, inplace=True)

# %% [markdown]
# Missing and Null Values

# %%
data.isnull().sum()
# Out:
# Date                   0
# Region                 0
# Category               0
# Supplier               0
# Warehouse              0
# Order Status           0
# Units Sold             0
# Inventory Level        0
# Transportation Cost    0
# Order Accuracy         0
# Lead Time (Days)       0
# Backorder              0
# Cost of Goods Sold     0
# Average Inventory      0
# Warehouse Capacity     0
# dtype: int64

# %%
# Inference
# There is no missing values in the Dataset

# %%
data.describe()
# Out:
#         Units Sold  Inventory Level  Transportation Cost  Lead Time (Days)  \
# count  1200.000000      1200.000000          1200.000000       1200.000000
# mean    533.892500      2530.473333          7723.518494         15.739167
# std     275.469524      1416.945265          4202.727652          8.442187
# min      50.000000       101.000000           509.098991          1.000000
# 25%     298.000000      1261.750000          4145.882050          8.000000
# 50%     529.000000      2623.500000          7759.647979         16.000000
# 75%     777.000000      3726.250000         11154.018832         23.000000
# max     999.000000      4999.000000         14997.814050         29.000000
#
#        Cost of Goods Sold  Average Inventory  Warehouse Capacity
# count         1200.000000        1200.000000         1200.000000
# mean         59370.480017        2529.588333         7425.831667
# std          44542.532052        1000.512796         1460.827133
# ...

# %% [markdown]
# Looking Out For Duplicate Values

# %%
data.duplicated().sum()
# Out:
# 0

# %%
# We have zero duplicated values in our data

# %% [markdown]
# Dropping NA Values

# %%
data.dropna()
# Out:
#             Date Region     Category    Supplier    Warehouse Order Status  \
# 0     14-01-2020  North  Accessories  Supplier A  Warehouse 1    Fulfilled
# 1     15-11-2020   East    Furniture  Supplier D  Warehouse 2    Fulfilled
# 2     16-04-2020   East    Furniture  Supplier C  Warehouse 2    Fulfilled
# 3     17-04-2020  South  Accessories  Supplier D  Warehouse 2     Canceled
# 4     18-04-2020  North  Accessories  Supplier C  Warehouse 2    Fulfilled
# ...          ...    ...          ...         ...          ...          ...
# 1195  05-01-2023   East  Electronics  Supplier C  Warehouse 2      Pending
# 1196  04-01-2023   East     Clothing  Supplier A  Warehouse 3    Fulfilled
# 1197  03-01-2023  North  Accessories  Supplier C  Warehouse 2    Fulfilled
# 1198  02-01-2023   West     Clothing  Supplier D  Warehouse 1      Pending
# 1199  01-01-2023   East  Electronics  Supplier A  Warehouse 1    Fulfilled
#
# ...

# %%
data.head(10)
# Out:
#          Date Region     Category    Supplier    Warehouse Order Status  \
# 0  14-01-2020  North  Accessories  Supplier A  Warehouse 1    Fulfilled
# 1  15-11-2020   East    Furniture  Supplier D  Warehouse 2    Fulfilled
# 2  16-04-2020   East    Furniture  Supplier C  Warehouse 2    Fulfilled
# 3  17-04-2020  South  Accessories  Supplier D  Warehouse 2     Canceled
# 4  18-04-2020  North  Accessories  Supplier C  Warehouse 2    Fulfilled
# 5  19-04-2020  South  Electronics  Supplier A  Warehouse 1     Canceled
# 6  20-04-2020   West    Furniture  Supplier A  Warehouse 2      Pending
# 7  21-04-2020  North  Accessories  Supplier C  Warehouse 1     Canceled
# 8  22-04-2020   East     Clothing  Supplier C  Warehouse 3    Fulfilled
# 9  23-04-2020   East     Clothing  Supplier A  Warehouse 1    Fulfilled
#
#    Units Sold  Inventory Level  Transportation Cost  Order Accuracy  \
# 0         302             2124              1103.84               1
# ...

# %% [markdown]
# Rounding To 2 Decimal Places

# %%
data["Transportation Cost"] = data["Transportation Cost"].round(2)
data["Cost of Goods Sold"] = data["Cost of Goods Sold"].round(2)

# %%
data
# Out:
#             Date Region     Category    Supplier    Warehouse Order Status  \
# 0     14-01-2020  North  Accessories  Supplier A  Warehouse 1    Fulfilled
# 1     15-11-2020   East    Furniture  Supplier D  Warehouse 2    Fulfilled
# 2     16-04-2020   East    Furniture  Supplier C  Warehouse 2    Fulfilled
# 3     17-04-2020  South  Accessories  Supplier D  Warehouse 2     Canceled
# 4     18-04-2020  North  Accessories  Supplier C  Warehouse 2    Fulfilled
# ...          ...    ...          ...         ...          ...          ...
# 1195  05-01-2023   East  Electronics  Supplier C  Warehouse 2      Pending
# 1196  04-01-2023   East     Clothing  Supplier A  Warehouse 3    Fulfilled
# 1197  03-01-2023  North  Accessories  Supplier C  Warehouse 2    Fulfilled
# 1198  02-01-2023   West     Clothing  Supplier D  Warehouse 1      Pending
# 1199  01-01-2023   East  Electronics  Supplier A  Warehouse 1    Fulfilled
#
# ...

# %%
Changing datatype - Converting Boolean to Int

# %%
data["Order Accuracy"] = data["Order Accuracy"].astype(int)

# %%
data["Backorder"] = data["Backorder"].astype(int)

# %%
data
# Out:
#             Date Region     Category    Supplier    Warehouse Order Status  \
# 0     14-01-2020  North  Accessories  Supplier A  Warehouse 1    Fulfilled
# 1     15-11-2020   East    Furniture  Supplier D  Warehouse 2    Fulfilled
# 2     16-04-2020   East    Furniture  Supplier C  Warehouse 2    Fulfilled
# 3     17-04-2020  South  Accessories  Supplier D  Warehouse 2     Canceled
# 4     18-04-2020  North  Accessories  Supplier C  Warehouse 2    Fulfilled
# ...          ...    ...          ...         ...          ...          ...
# 1195  05-01-2023   East  Electronics  Supplier C  Warehouse 2      Pending
# 1196  04-01-2023   East     Clothing  Supplier A  Warehouse 3    Fulfilled
# 1197  03-01-2023  North  Accessories  Supplier C  Warehouse 2    Fulfilled
# 1198  02-01-2023   West     Clothing  Supplier D  Warehouse 1      Pending
# 1199  01-01-2023   East  Electronics  Supplier A  Warehouse 1    Fulfilled
#
# ...

# %%
data.head(20)
# Out:
#           Date Region     Category    Supplier    Warehouse Order Status  \
# 0   14-01-2020  North  Accessories  Supplier A  Warehouse 1    Fulfilled
# 1   15-11-2020   East    Furniture  Supplier D  Warehouse 2    Fulfilled
# 2   16-04-2020   East    Furniture  Supplier C  Warehouse 2    Fulfilled
# 3   17-04-2020  South  Accessories  Supplier D  Warehouse 2     Canceled
# 4   18-04-2020  North  Accessories  Supplier C  Warehouse 2    Fulfilled
# 5   19-04-2020  South  Electronics  Supplier A  Warehouse 1     Canceled
# 6   20-04-2020   West    Furniture  Supplier A  Warehouse 2      Pending
# 7   21-04-2020  North  Accessories  Supplier C  Warehouse 1     Canceled
# 8   22-04-2020   East     Clothing  Supplier C  Warehouse 3    Fulfilled
# 9   23-04-2020   East     Clothing  Supplier A  Warehouse 1    Fulfilled
# 10  24-04-2020   West     Clothing  Supplier D  Warehouse 3    Fulfilled
# 11  25-04-2020   East    Furniture  Supplier A  Warehouse 1    Fulfilled
# ...

# %%
# Capping method
data["Lead Time (Days)"] = data["Lead Time (Days)"].clip(lower=2, upper=27)

# %%
data
# Out:
#             Date Region     Category    Supplier    Warehouse Order Status  \
# 0     14-01-2020  North  Accessories  Supplier A  Warehouse 1    Fulfilled
# 1     15-11-2020   East    Furniture  Supplier D  Warehouse 2    Fulfilled
# 2     16-04-2020   East    Furniture  Supplier C  Warehouse 2    Fulfilled
# 3     17-04-2020  South  Accessories  Supplier D  Warehouse 2     Canceled
# 4     18-04-2020  North  Accessories  Supplier C  Warehouse 2    Fulfilled
# ...          ...    ...          ...         ...          ...          ...
# 1195  05-01-2023   East  Electronics  Supplier C  Warehouse 2      Pending
# 1196  04-01-2023   East     Clothing  Supplier A  Warehouse 3    Fulfilled
# 1197  03-01-2023  North  Accessories  Supplier C  Warehouse 2    Fulfilled
# 1198  02-01-2023   West     Clothing  Supplier D  Warehouse 1      Pending
# 1199  01-01-2023   East  Electronics  Supplier A  Warehouse 1    Fulfilled
#
# ...

# %%
data.to_csv('Inventory_SupplyChain_Dataset.csv', index=False)
